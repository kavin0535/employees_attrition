# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

df = pd.read_csv("../data/Final dataset Attrition.csv")

df["Attrition"] = df["Attrition"].map({"Yes":1, "No":0})

print(df.info())

sns.countplot(x="Attrition", data=df)
plt.show()

sns.boxplot(x="Attrition", y="MonthlyIncome", data=df)
plt.show()

sns.countplot(x="OverTime", hue="Attrition", data=df)
plt.show()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 1470 entries, 0 to 1469
# Data columns (total 33 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Age                      1470 non-null   int64
#  1   Attrition                1470 non-null   int64
#  2   BusinessTravel           1470 non-null   str
#  3   Department               1470 non-null   str
#  4   DistanceFromHome         1470 non-null   int64
#  5   Gender                   1470 non-null   str
#  6   JobInvolvement           1470 non-null   int64
#  7   JobLevel                 1470 non-null   int64
#  8   JobRole                  1470 non-null   str
#  9   JobSatisfaction          1470 non-null   int64
#  10  MaritalStatus            1470 non-null   str
#  11  MonthlyIncome            1470 non-null   int64
#  12  NumCompaniesWorked       1470 non-null   int64
#  13  OverTime                 1470 non-null   str
#  14  PercentSalaryHike        1470 non-null   int64
#  15  PerformanceRating        1470 non-null   int64
#  16  StockOptionLevel         1470 non-null   int64
#  17  TotalWorkingYears        1470 non-null   int64
#  18  TrainingTimesLastYear    1470 non-null   int64
#  19  YearsAtCompany           1470 non-null   int64
#  20  YearsSinceLastPromotion  1470 non-null   int64
#  21  YearsWithCurrManager     1470 non-null   int64
#  22  Higher_Education         1470 non-null   str
#  23  Date_of_Hire             1470 non-null   str
#  24  Date_of_termination      0 non-null      float64
#  25  Status_of_leaving        1470 non-null   str
#  26  Mode_of_work             1470 non-null   str
#  27  Leaves                   1470 non-null   int64
#  28  Absenteeism              1470 non-null   int64
#  29  Work_accident            1470 non-null   str
#  30  Source_of_Hire           1470 non-null   str
#  31  Job_mode                 1470 non-null   str
#  32  Unnamed: 32              0 non-null      float64
# dtypes: float64(2), int64(18), str(13)
# memory usage: 379.1 KB
# None
